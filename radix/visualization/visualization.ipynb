# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Updated filename for Phase 2
df = pd.read_csv('phase2_averaged_results.csv')

# Calculate Throughput for all versions
# Formula: (N / (ms / 1000)) / 1e6
df['Throughput_Naive'] = (df['Size'] / (df['GPU_Naive_ms'] / 1000.0)) / 1e6
df['Throughput_Opt'] = (df['Size'] / (df['GPU_Opt_ms'] / 1000.0)) / 1e6
df['Throughput_Thrust'] = (df['Size'] / (df['GPU_Lib_ms'] / 1000.0)) / 1e6

# Calculate the Speedup of Optimized vs Naive
df['Opt_vs_Naive_Speedup'] = df['GPU_Naive_ms'] / df['GPU_Opt_ms']

print(f"Phase 2 Data Loaded: {len(df)} points.")
print(f"Max Speedup (Opt vs Naive): {df['Opt_vs_Naive_Speedup'].max():.2f}x")
# Out:
# Phase 2 Data Loaded: 16 points.
# Max Speedup (Opt vs Naive): 13.76x

# %%
# Updated Visual Style
COLORS = {
    'CPU': 'tab:blue',
    'Naive': 'tab:orange', 
    'Optimized': 'tab:green',  # Green signifies the successful Phase 2 optimization
    'Thrust': 'tab:purple'
}

MARKERS = {
    'CPU': 'o',
    'Naive': '^',
    'Optimized': '*', # Star marker to make it stand out
    'Thrust': 'D'
}

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# --- Subplot 1: Execution Time (Log-Log) ---
ax1.loglog(df['Size'], df['CPU_ms'], label='CPU Sequential', 
           color=COLORS['CPU'], marker=MARKERS['CPU'], alpha=0.6)

ax1.loglog(df['Size'], df['GPU_Naive_ms'], label='GPU Parallel (Naive)', 
           color=COLORS['Naive'], marker=MARKERS['Naive'])

ax1.loglog(df['Size'], df['GPU_Opt_ms'], label='GPU Parallel (Shared Opt)', 
           color=COLORS['Optimized'], marker=MARKERS['Optimized'], markersize=10)

ax1.loglog(df['Size'], df['GPU_Lib_ms'], label='GPU Parallel (Thrust)', 
           color=COLORS['Thrust'], marker=MARKERS['Thrust'])

ax1.set_title('Radix Sort Phase 2: Execution Time Scaling', fontsize=15)
ax1.set_xlabel('Dataset Size (N)', fontsize=12)
ax1.set_ylabel('Time (ms)', fontsize=12)
ax1.grid(True, which="both", alpha=0.3)
ax1.legend()

# --- Subplot 2: Throughput Scalability (Linear-Log) ---
ax2.semilogx(df['Size'], df['Throughput_Naive'], label='Naive Throughput', 
             color=COLORS['Naive'], marker=MARKERS['Naive'])

ax2.semilogx(df['Size'], df['Throughput_Opt'], label='Optimized Throughput', 
             color=COLORS['Optimized'], marker=MARKERS['Optimized'], markersize=10)

ax2.semilogx(df['Size'], df['Throughput_Thrust'], label='Thrust Throughput', 
             color=COLORS['Thrust'], marker=MARKERS['Thrust'])

ax2.set_title('Radix Sort Phase 2: Throughput Scalability', fontsize=15)
ax2.set_xlabel('Dataset Size (N)', fontsize=12)
ax2.set_ylabel('Million Elements / sec', fontsize=12)
ax2.grid(True, which="both", alpha=0.3)
ax2.legend()

plt.tight_layout()
plt.show()

# %%
# Updated filename for Phase 3
df = pd.read_csv('phase3_averaged_results.csv')

# Calculate Throughput for all versions
# Formula: (N / (ms / 1000)) / 1e6
df['Throughput_Naive'] = (df['Size'] / (df['GPU_Naive_ms'] / 1000.0)) / 1e6
df['Throughput_Opt'] = (df['Size'] / (df['GPU_Opt_ms'] / 1000.0)) / 1e6
df['Throughput_Thrust'] = (df['Size'] / (df['GPU_Lib_ms'] / 1000.0)) / 1e6

# Calculate the Speedup of Optimized vs Naive
df['Opt_vs_Naive_Speedup'] = df['GPU_Naive_ms'] / df['GPU_Opt_ms']

print(f"Phase 3 Data Loaded: {len(df)} points.")
print(f"Max Speedup (Opt vs Naive): {df['Opt_vs_Naive_Speedup'].max():.2f}x")
# Out:
# Phase 3 Data Loaded: 16 points.
# Max Speedup (Opt vs Naive): 12.45x

# %%
# Updated Visual Style
COLORS = {
    'CPU': 'tab:blue',
    'Naive': 'tab:orange', 
    'Optimized': 'tab:green',  # Green signifies the successful Phase 2 optimization
    'Thrust': 'tab:purple'
}

MARKERS = {
    'CPU': 'o',
    'Naive': '^',
    'Optimized': '*', # Star marker to make it stand out
    'Thrust': 'D'
}

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))

# --- Subplot 1: Execution Time (Log-Log) ---
ax1.loglog(df['Size'], df['CPU_ms'], label='CPU Sequential', 
           color=COLORS['CPU'], marker=MARKERS['CPU'], alpha=0.6)

ax1.loglog(df['Size'], df['GPU_Naive_ms'], label='GPU Parallel (Naive)', 
           color=COLORS['Naive'], marker=MARKERS['Naive'])

ax1.loglog(df['Size'], df['GPU_Opt_ms'], label='GPU Parallel (Shared Opt)', 
           color=COLORS['Optimized'], marker=MARKERS['Optimized'], markersize=10)

ax1.loglog(df['Size'], df['GPU_Lib_ms'], label='GPU Parallel (Thrust)', 
           color=COLORS['Thrust'], marker=MARKERS['Thrust'])

ax1.set_title('Radix Sort Phase 3: Execution Time Scaling', fontsize=15)
ax1.set_xlabel('Dataset Size (N)', fontsize=12)
ax1.set_ylabel('Time (ms)', fontsize=12)
ax1.grid(True, which="both", alpha=0.3)
ax1.legend()

# --- Subplot 2: Throughput Scalability (Linear-Log) ---
ax2.semilogx(df['Size'], df['Throughput_Naive'], label='Naive Throughput', 
             color=COLORS['Naive'], marker=MARKERS['Naive'])

ax2.semilogx(df['Size'], df['Throughput_Opt'], label='Optimized Throughput', 
             color=COLORS['Optimized'], marker=MARKERS['Optimized'], markersize=10)

ax2.semilogx(df['Size'], df['Throughput_Thrust'], label='Thrust Throughput', 
             color=COLORS['Thrust'], marker=MARKERS['Thrust'])

ax2.set_title('Radix Sort Phase 3: Throughput Scalability', fontsize=15)
ax2.set_xlabel('Dataset Size (N)', fontsize=12)
ax2.set_ylabel('Million Elements / sec', fontsize=12)
ax2.grid(True, which="both", alpha=0.3)
ax2.legend()

plt.tight_layout()
plt.show()

# %%
# 1. Load the data directly from the CSV file
df = pd.read_csv("phase4_results.csv")

# --- HARDWARE CONSTANTS ---
PEAK_BANDWIDTH_GBPS = 1555.0  # GB/s
PEAK_COMPUTE_GOPS = 19500.0   # Giga-Ops/sec (INT32)

# --- DERIVED CALCULATIONS ---
# 1. Speedup over CPU
df['Speedup_Naive'] = df['CPU_ms'] / df['GPU_Naive_ms']
df['Speedup_P2'] = df['CPU_ms'] / df['GPU_P2_Opt_ms']
df['Speedup_P3'] = df['CPU_ms'] / df['GPU_P3_Opt_ms']
df['Speedup_Thrust'] = df['CPU_ms'] / df['GPU_Thrust_ms']

# 2. Bandwidth (For Radix Sort: 4 passes [0-9999 data] * 2 [Read+Write] * 4 bytes per int = 32 bytes/element)
BYTES_PER_ELEMENT = 32 
# We calculate bandwidth for the largest dataset to show peak utilization
N_max = df['Size'].max()
row_max = df[df['Size'] == N_max].iloc[0]

def calc_bw(time_ms):
    time_s = time_ms / 1000.0
    total_bytes = N_max * BYTES_PER_ELEMENT
    return (total_bytes / time_s) / 1e9 # Convert to GB/s

bw_naive = calc_bw(row_max['GPU_Naive_ms'])
bw_p2 = calc_bw(row_max['GPU_P2_Opt_ms'])
bw_p3 = calc_bw(row_max['GPU_P3_Opt_ms'])
bw_thrust = calc_bw(row_max['GPU_Thrust_ms'])

# 3. Arithmetic Intensity (Operations per Byte)
# Radix sort is extremely memory bound. ~10 integer ops per element, 32 bytes accessed.
ARITHMETIC_INTENSITY = 10.0 / BYTES_PER_ELEMENT
gops_naive = (N_max * 10 / (row_max['GPU_Naive_ms'] / 1000.0)) / 1e9
gops_p2 = (N_max * 10 / (row_max['GPU_P2_Opt_ms'] / 1000.0)) / 1e9
gops_p3 = (N_max * 10 / (row_max['GPU_P3_Opt_ms'] / 1000.0)) / 1e9
gops_thrust = (N_max * 10 / (row_max['GPU_Thrust_ms'] / 1000.0)) / 1e9

# Set a consistent style for all following plots
plt.style.use('seaborn-v0_8-whitegrid')

# %%
fig, ax = plt.subplots(figsize=(10, 7))

ax.plot(df['Size'], df['Speedup_Naive'], marker='^', label='GPU Naive (P1)', color='#2ca02c')
ax.plot(df['Size'], df['Speedup_P2'], marker='*', markersize=10, label='GPU Shared (P2)', color='green')
ax.plot(df['Size'], df['Speedup_P3'], marker='p', markersize=10, label='GPU Coalesced (P3)', color='red')
ax.plot(df['Size'], df['Speedup_Thrust'], marker='D', label='GPU Thrust (Lib)', color='purple')
ax.axhline(1, color='gray', linestyle='--', label='CPU Baseline (1x)')

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Dataset Size (N)', fontsize=14)
ax.set_ylabel('Speedup Factor vs CPU', fontsize=14)
ax.set_title('Algorithm Speedup Over CPU Baseline', fontsize=16)
ax.legend(fontsize=12)

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 7))

labels = ['Naive', 'Shared (P2)', 'Coalesced (P3)', 'Thrust']
bandwidths = [bw_naive, bw_p2, bw_p3, bw_thrust]
colors = ['#2ca02c', 'green', 'red', 'purple']

bars = ax.bar(labels, bandwidths, color=colors, alpha=0.8, edgecolor='black')
ax.axhline(PEAK_BANDWIDTH_GBPS, color='red', linestyle='--', linewidth=2, 
           label=f'Hardware Peak ({PEAK_BANDWIDTH_GBPS} GB/s)')

# Add text labels on bars
for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval + (PEAK_BANDWIDTH_GBPS*0.02), 
            f'{yval:.1f} GB/s', ha='center', va='bottom', fontweight='bold')

ax.set_ylim(0, PEAK_BANDWIDTH_GBPS * 1.1)
ax.set_ylabel('Effective Bandwidth (GB/s)', fontsize=14)
ax.set_title(f'Memory Bandwidth Utilization (N={N_max})', fontsize=16)
ax.legend(fontsize=12)

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 7))

# Create Roofline bounds
x_roof = np.logspace(-2, 3, 100)
y_roof = np.minimum(PEAK_COMPUTE_GOPS, x_roof * PEAK_BANDWIDTH_GBPS)

ax.plot(x_roof, y_roof, color='black', linewidth=2, label='Hardware Roofline')
ax.fill_between(x_roof, 0, y_roof, color='lightgray', alpha=0.3)

# Plot algorithm points
ax.scatter([ARITHMETIC_INTENSITY], [gops_naive], color='#2ca02c', s=150, marker='^', zorder=5, label='Naive')
ax.scatter([ARITHMETIC_INTENSITY], [gops_p2], color='green', s=200, marker='*', zorder=5, label='Shared (P2)')
ax.scatter([ARITHMETIC_INTENSITY], [gops_p3], color='red', s=150, marker='p', zorder=5, label='Coalesced (P3)')
ax.scatter([ARITHMETIC_INTENSITY], [gops_thrust], color='purple', s=150, marker='D', zorder=5, label='Thrust')

ax.set_xscale('log')
ax.set_yscale('log')
ax.set_xlabel('Arithmetic Intensity (Ops / Byte)', fontsize=14)
ax.set_ylabel('Performance (Giga-Ops / sec)', fontsize=14)
ax.set_title('Roofline Model (Integer Performance)', fontsize=16)

# Annotate the ridge point
ridge_point = PEAK_COMPUTE_GOPS / PEAK_BANDWIDTH_GBPS
ax.axvline(ridge_point, color='gray', linestyle=':', label=f'Ridge Point ({ridge_point:.1f} Ops/B)')
ax.legend(fontsize=12)

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 7))

# Calculate Throughput: Million Elements per Second (MElem/s)
df['Thru_Naive'] = (df['Size'] / (df['GPU_Naive_ms'] / 1000.0)) / 1e6
df['Thru_P2'] = (df['Size'] / (df['GPU_P2_Opt_ms'] / 1000.0)) / 1e6
df['Thru_P3'] = (df['Size'] / (df['GPU_P3_Opt_ms'] / 1000.0)) / 1e6
df['Thru_Thrust'] = (df['Size'] / (df['GPU_Thrust_ms'] / 1000.0)) / 1e6

# Plot the throughput
ax.plot(df['Size'], df['Thru_Naive'], marker='^', label='Naive', color='#2ca02c')
ax.plot(df['Size'], df['Thru_P2'], marker='*', markersize=10, label='Shared (P2)', color='green')
ax.plot(df['Size'], df['Thru_P3'], marker='p', markersize=10, label='Coalesced (P3)', color='red')
ax.plot(df['Size'], df['Thru_Thrust'], marker='D', label='Thrust (Lib)', color='purple')

ax.set_xscale('log')
# Keeping Y-axis linear is standard for throughput to show the "plateau" as the GPU fills up
ax.set_xlabel('Dataset Size (N)', fontsize=14)
ax.set_ylabel('Throughput (Million Elements / sec)', fontsize=14)
ax.set_title('Radix Sort: Throughput Scalability', fontsize=16)
ax.legend(fontsize=12)

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 7))

# Plot raw execution times (in milliseconds)
ax.plot(df['Size'], df['CPU_ms'], marker='o', label='CPU Sequential', color='#1f77b4')
ax.plot(df['Size'], df['GPU_Naive_ms'], marker='^', label='GPU Naive (P1)', color='#2ca02c')
ax.plot(df['Size'], df['GPU_P2_Opt_ms'], marker='*', markersize=10, label='GPU Shared (P2)', color='green')
ax.plot(df['Size'], df['GPU_P3_Opt_ms'], marker='p', markersize=10, label='GPU Coalesced (P3)', color='red')
ax.plot(df['Size'], df['GPU_Thrust_ms'], marker='D', label='GPU Thrust (Lib)', color='purple')

# Use Log-Log scale because the data spans from 1,000 to 33,000,000
ax.set_xscale('log')
ax.set_yscale('log')

ax.set_xlabel('Dataset Size (N)', fontsize=14)
ax.set_ylabel('Execution Time (ms)', fontsize=14)
ax.set_title('Radix Sort: Execution Time Scaling', fontsize=16)
ax.legend(fontsize=12)

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(9, 6))

# Extract the execution times for the absolute largest dataset (N = 33,554,432)
labels = ['CPU Baseline', 'GPU Naive', 'GPU Shared (P2)', 'GPU Coalesced (P3)', 'Thrust (Lib)']
times = [row_max['CPU_ms'], row_max['GPU_Naive_ms'], row_max['GPU_P2_Opt_ms'], row_max['GPU_P3_Opt_ms'], row_max['GPU_Thrust_ms']]
colors = ['#1f77b4', '#2ca02c', 'green', 'red', 'purple']

bars = ax.bar(labels, times, color=colors, alpha=0.8, edgecolor='black')

# Add the exact millisecond values on top of the bars so the audience can read them instantly
for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval + 10, 
            f'{yval:.1f} ms', ha='center', va='bottom', fontweight='bold', fontsize=11)

ax.set_ylabel('Execution Time (ms) - Lower is Better', fontsize=14)
ax.set_title(f'Execution Time at Maximum Load (N = {N_max})', fontsize=16)

# Optional: Add a subtle grid for readability
ax.yaxis.grid(True, linestyle='--', alpha=0.7)
ax.set_axisbelow(True)

plt.tight_layout()
plt.show()

# %%
# Create a single figure with 1 row and 3 columns
# We make it very wide (24) to fit all three cleanly
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(24, 7))

# =======================================================
# --- Plot 1 (Left Side): Algorithm Speedup ---
# =======================================================
ax1.plot(df['Size'], df['Speedup_Naive'], marker='^', label='GPU Naive (P1)', color='#2ca02c')
ax1.plot(df['Size'], df['Speedup_P2'], marker='*', markersize=10, label='GPU Shared (P2)', color='green')
ax1.plot(df['Size'], df['Speedup_P3'], marker='p', markersize=10, label='GPU Coalesced (P3)', color='red')
ax1.plot(df['Size'], df['Speedup_Thrust'], marker='D', label='GPU Thrust (Lib)', color='purple')
ax1.axhline(1, color='gray', linestyle='--', label='CPU Baseline (1x)')

ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('Dataset Size (N)', fontsize=14)
ax1.set_ylabel('Speedup Factor vs CPU', fontsize=14)
ax1.set_title('Algorithm Speedup Over CPU Baseline', fontsize=16)
ax1.legend(fontsize=12)

# =======================================================
# --- Plot 2 (Middle): Memory Bandwidth Utilization ---
# =======================================================
labels = ['Naive', 'Shared (P2)', 'Coalesced (P3)', 'Thrust']
bandwidths = [bw_naive, bw_p2, bw_p3, bw_thrust]
colors = ['#2ca02c', 'green', 'red', 'purple']

bars = ax2.bar(labels, bandwidths, color=colors, alpha=0.8, edgecolor='black')
ax2.axhline(PEAK_BANDWIDTH_GBPS, color='red', linestyle='--', linewidth=2, 
            label=f'Hardware Peak ({PEAK_BANDWIDTH_GBPS} GB/s)')

# Add text labels on bars
for bar in bars:
    yval = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2, yval + (PEAK_BANDWIDTH_GBPS*0.02), 
             f'{yval:.1f} GB/s', ha='center', va='bottom', fontweight='bold')

ax2.set_ylim(0, PEAK_BANDWIDTH_GBPS * 1.1)
ax2.set_ylabel('Effective Bandwidth (GB/s)', fontsize=14)
ax2.set_title(f'Memory Bandwidth Utilization (N={N_max})', fontsize=16)
ax2.legend(fontsize=12)

# =======================================================
# --- Plot 3 (Right Side): Roofline Model ---
# =======================================================
# Create Roofline bounds
x_roof = np.logspace(-2, 3, 100)
y_roof = np.minimum(PEAK_COMPUTE_GOPS, x_roof * PEAK_BANDWIDTH_GBPS)

ax3.plot(x_roof, y_roof, color='black', linewidth=2, label='Hardware Roofline')
ax3.fill_between(x_roof, 0, y_roof, color='lightgray', alpha=0.3)

# Plot algorithm points
ax3.scatter([ARITHMETIC_INTENSITY], [gops_naive], color='#2ca02c', s=150, marker='^', zorder=5, label='Naive')
ax3.scatter([ARITHMETIC_INTENSITY], [gops_p2], color='green', s=200, marker='*', zorder=5, label='Shared (P2)')
ax3.scatter([ARITHMETIC_INTENSITY], [gops_p3], color='red', s=150, marker='p', zorder=5, label='Coalesced (P3)')
ax3.scatter([ARITHMETIC_INTENSITY], [gops_thrust], color='purple', s=150, marker='D', zorder=5, label='Thrust')

ax3.set_xscale('log')
ax3.set_yscale('log')
ax3.set_xlabel('Arithmetic Intensity (Ops / Byte)', fontsize=14)
ax3.set_ylabel('Performance (Giga-Ops / sec)', fontsize=14)
ax3.set_title('Roofline Model (Integer Performance)', fontsize=16)

# Annotate the ridge point
ridge_point = PEAK_COMPUTE_GOPS / PEAK_BANDWIDTH_GBPS
ax3.axvline(ridge_point, color='gray', linestyle=':', label=f'Ridge Point ({ridge_point:.1f} Ops/B)')
ax3.legend(fontsize=12)

# =======================================================
# --- Final Render ---
# =======================================================
# tight_layout ensures the labels don't overlap between the plots
plt.tight_layout()
plt.show()
